# %% [markdown]
# <a href="https://colab.research.google.com/github/AtharvaKodgule/iris-data-exploration/blob/main/iris_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import all necessary libraries with error handling
try:
    import pandas as pd
    print("✅ pandas imported successfully")
except ImportError:
    print("❌ Error importing pandas. Installing...")
    # !pip install pandas
    import pandas as pd
    print("✅ pandas installed and imported")

try:
    import numpy as np
    print("✅ numpy imported successfully")
except ImportError:
    print("❌ Error importing numpy. Installing...")
    # !pip install numpy
    import numpy as np
    print("✅ numpy installed and imported")

try:
    import matplotlib.pyplot as plt
    print("✅ matplotlib imported successfully")
except ImportError:
    print("❌ Error importing matplotlib. Installing...")
    # !pip install matplotlib
    import matplotlib.pyplot as plt
    print("✅ matplotlib installed and imported")

try:
    import seaborn as sns
    print("✅ seaborn imported successfully")
except ImportError:
    print("❌ Error importing seaborn. Installing...")
    # !pip install seaborn
    import seaborn as sns
    print("✅ seaborn installed and imported")

try:
    from scipy import stats
    print("✅ scipy imported successfully")
except ImportError:
    print("❌ Error importing scipy. Installing...")
    # !pip install scipy
    from scipy import stats
    print("✅ scipy installed and imported")

import warnings
warnings.filterwarnings('ignore')

# Set up plotting style
plt.style.use('default')
sns.set_palette("husl")

print("\n🎉 ALL LIBRARIES IMPORTED SUCCESSFULLY!")
# Out:
# ✅ pandas imported successfully
# ✅ numpy imported successfully
# ✅ matplotlib imported successfully
# ✅ seaborn imported successfully
# ✅ scipy imported successfully
#
# 🎉 ALL LIBRARIES IMPORTED SUCCESSFULLY!

# %%
# Load the Iris dataset
df = pd.read_csv('iris.csv')

print("=== IRIS DATASET OVERVIEW ===")
print(f"Dataset shape: {df.shape}")
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\n=== COLUMN NAMES ===")
print(df.columns.tolist())
print("\n=== FIRST 5 ROWS ===")
print(df.head())
print("\n=== LAST 5 ROWS ===")
print(df.tail())
# Out:
# === IRIS DATASET OVERVIEW ===
# Dataset shape: (150, 5)
# Number of rows: 150
# Number of columns: 5
#
# === COLUMN NAMES ===
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#
# === FIRST 5 ROWS ===
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# === LAST 5 ROWS ===
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# ...

# %%
# Display detailed information about the dataset
print("=== DATA TYPES AND INFO ===")
print(df.info())
print("\n=== DATA TYPES SUMMARY ===")
print(df.dtypes)
print("\n=== UNIQUE VALUES IN EACH COLUMN ===")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
    if df[col].nunique() < 10:  # Show unique values if less than 10
        print(f"  Values: {df[col].unique()}")
# Out:
# === DATA TYPES AND INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# === DATA TYPES SUMMARY ===
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
# === UNIQUE VALUES IN EACH COLUMN ===
# sepal_length: 35 unique values
# sepal_width: 23 unique values
# petal_length: 43 unique values
# petal_width: 22 unique values
# species: 3 unique values
#   Values: ['setosa' 'versicolor' 'virginica']

# %%
# Check for missing values
print("=== MISSING VALUES ANALYSIS ===")
missing_values = df.isnull().sum()
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    'Column': df.columns,
    'Missing Count': missing_values,
    'Missing Percentage': missing_percentage
})

print(missing_df)

if missing_values.sum() == 0:
    print("\n✅ Great! No missing values found in the dataset.")
else:
    print(f"\n⚠️ Total missing values: {missing_values.sum()}")

# Visualize missing values if any
if missing_values.sum() > 0:
    plt.figure(figsize=(10, 6))
    sns.heatmap(df.isnull(), cbar=True, cmap='viridis')
    plt.title('Missing Values Heatmap')
    plt.show()
# Out:
# === MISSING VALUES ANALYSIS ===
#                     Column  Missing Count  Missing Percentage
# sepal_length  sepal_length              0                 0.0
# sepal_width    sepal_width              0                 0.0
# petal_length  petal_length              0                 0.0
# petal_width    petal_width              0                 0.0
# species            species              0                 0.0
#
# ✅ Great! No missing values found in the dataset.

# %%
# Check for missing values
print("=== MISSING VALUES ANALYSIS ===")
missing_values = df.isnull().sum()
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    'Column': df.columns,
    'Missing Count': missing_values,
    'Missing Percentage': missing_percentage
})

print(missing_df)

if missing_values.sum() == 0:
    print("\n✅ Great! No missing values found in the dataset.")
else:
    print(f"\n⚠️ Total missing values: {missing_values.sum()}")

# Visualize missing values if any
if missing_values.sum() > 0:
    plt.figure(figsize=(10, 6))
    sns.heatmap(df.isnull(), cbar=True, cmap='viridis')
    plt.title('Missing Values Heatmap')
    plt.show()
# Out:
# === MISSING VALUES ANALYSIS ===
#                     Column  Missing Count  Missing Percentage
# sepal_length  sepal_length              0                 0.0
# sepal_width    sepal_width              0                 0.0
# petal_length  petal_length              0                 0.0
# petal_width    petal_width              0                 0.0
# species            species              0                 0.0
#
# ✅ Great! No missing values found in the dataset.

# %%
# Generate descriptive statistics
print("=== DESCRIPTIVE STATISTICS ===")
print(df.describe())

# For numerical columns only
numerical_cols = df.select_dtypes(include=[np.number]).columns
print(f"\nNumerical columns: {numerical_cols.tolist()}")

# Additional statistics
print("\n=== ADDITIONAL STATISTICS ===")
for col in numerical_cols:
    print(f"\n{col}:")
    print(f"  Mean: {df[col].mean():.3f}")
    print(f"  Median: {df[col].median():.3f}")
    print(f"  Mode: {df[col].mode().iloc[0]:.3f}")
    print(f"  Standard Deviation: {df[col].std():.3f}")
    print(f"  Variance: {df[col].var():.3f}")
    print(f"  Range: {df[col].max() - df[col].min():.3f}")
    print(f"  IQR: {df[col].quantile(0.75) - df[col].quantile(0.25):.3f}")
# Out:
# === DESCRIPTIVE STATISTICS ===
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
# Numerical columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
#
# === ADDITIONAL STATISTICS ===
#
# sepal_length:
#   Mean: 5.843
#   Median: 5.800
#   Mode: 5.000
#   Standard Deviation: 0.828
#   Variance: 0.686
#   Range: 3.600
#   IQR: 1.300
#
# sepal_width:
#   Mean: 3.054
#   Median: 3.000
#   Mode: 3.000
#   Standard Deviation: 0.434
#   Variance: 0.188
#   Range: 2.400
# ...

# %%
# Analyze the target variable (species)
# Assuming the target column is named 'species' or similar
target_col = None
for col in df.columns:
    if 'species' in col.lower() or 'class' in col.lower() or 'target' in col.lower():
        target_col = col
        break

if target_col is None:
    # If no obvious target column, assume it's the last column
    target_col = df.columns[-1]

print(f"=== TARGET VARIABLE ANALYSIS: {target_col} ===")
species_counts = df[target_col].value_counts()
print("Species distribution:")
print(species_counts)

# Calculate percentages
species_percentages = df[target_col].value_counts(normalize=True) * 100
print("\nSpecies distribution (percentages):")
for species, percentage in species_percentages.items():
    print(f"{species}: {percentage:.1f}%")

# Visualize species distribution
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Bar plot
species_counts.plot(kind='bar', ax=ax1, color=['skyblue', 'lightcoral', 'lightgreen'])
ax1.set_title('Species Distribution (Count)', fontsize=14, fontweight='bold')
ax1.set_xlabel('Species')
ax1.set_ylabel('Count')
ax1.tick_params(axis='x', rotation=45)

# Pie chart
ax2.pie(species_counts.values, labels=species_counts.index, autopct='%1.1f%%',
        colors=['skyblue', 'lightcoral', 'lightgreen'])
ax2.set_title('Species Distribution (Percentage)', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# === TARGET VARIABLE ANALYSIS: species ===
# Species distribution:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#
# Species distribution (percentages):
# setosa: 33.3%
# versicolor: 33.3%
# virginica: 33.3%

# %%
# Generate descriptive statistics
print("=== DESCRIPTIVE STATISTICS ===")
print(df.describe())

# For numerical columns only
numerical_cols = df.select_dtypes(include=[np.number]).columns
print(f"\nNumerical columns: {numerical_cols.tolist()}")

# Additional statistics
print("\n=== ADDITIONAL STATISTICS ===")
for col in numerical_cols:
    print(f"\n{col}:")
    print(f"  Mean: {df[col].mean():.3f}")
    print(f"  Median: {df[col].median():.3f}")
    print(f"  Mode: {df[col].mode().iloc[0]:.3f}")
    print(f"  Standard Deviation: {df[col].std():.3f}")
    print(f"  Variance: {df[col].var():.3f}")
    print(f"  Range: {df[col].max() - df[col].min():.3f}")
    print(f"  IQR: {df[col].quantile(0.75) - df[col].quantile(0.25):.3f}")
# Out:
# === DESCRIPTIVE STATISTICS ===
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
# Numerical columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
#
# === ADDITIONAL STATISTICS ===
#
# sepal_length:
#   Mean: 5.843
#   Median: 5.800
#   Mode: 5.000
#   Standard Deviation: 0.828
#   Variance: 0.686
#   Range: 3.600
#   IQR: 1.300
#
# sepal_width:
#   Mean: 3.054
#   Median: 3.000
#   Mode: 3.000
#   Standard Deviation: 0.434
#   Variance: 0.188
#   Range: 2.400
# ...

# %%
# Analyze the target variable (species)
# Assuming the target column is named 'species' or similar
target_col = None
for col in df.columns:
    if 'species' in col.lower() or 'class' in col.lower() or 'target' in col.lower():
        target_col = col
        break

if target_col is None:
    # If no obvious target column, assume it's the last column
    target_col = df.columns[-1]

print(f"=== TARGET VARIABLE ANALYSIS: {target_col} ===")
species_counts = df[target_col].value_counts()
print("Species distribution:")
print(species_counts)

# Calculate percentages
species_percentages = df[target_col].value_counts(normalize=True) * 100
print("\nSpecies distribution (percentages):")
for species, percentage in species_percentages.items():
    print(f"{species}: {percentage:.1f}%")

# Visualize species distribution
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Bar plot
species_counts.plot(kind='bar', ax=ax1, color=['skyblue', 'lightcoral', 'lightgreen'])
ax1.set_title('Species Distribution (Count)', fontsize=14, fontweight='bold')
ax1.set_xlabel('Species')
ax1.set_ylabel('Count')
ax1.tick_params(axis='x', rotation=45)

# Pie chart
ax2.pie(species_counts.values, labels=species_counts.index, autopct='%1.1f%%',
        colors=['skyblue', 'lightcoral', 'lightgreen'])
ax2.set_title('Species Distribution (Percentage)', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# === TARGET VARIABLE ANALYSIS: species ===
# Species distribution:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#
# Species distribution (percentages):
# setosa: 33.3%
# versicolor: 33.3%
# virginica: 33.3%

# %%
# Create histograms for all numerical features
numerical_cols = df.select_dtypes(include=[np.number]).columns

fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.ravel()

colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']

for i, col in enumerate(numerical_cols):
    axes[i].hist(df[col], bins=20, color=colors[i], alpha=0.7, edgecolor='black')
    axes[i].set_title(f'Distribution of {col}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')
    axes[i].grid(True, alpha=0.3)

    # Add statistics text
    mean_val = df[col].mean()
    std_val = df[col].std()
    axes[i].axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
# Create box plots for each feature grouped by species
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.ravel()

for i, col in enumerate(numerical_cols):
    sns.boxplot(data=df, x=target_col, y=col, ax=axes[i])
    axes[i].set_title(f'{col} by Species', fontsize=12, fontweight='bold')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# Check for outliers
print("=== OUTLIER DETECTION USING IQR METHOD ===")
for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"\n{col}:")
    print(f"  Lower bound: {lower_bound:.3f}")
    print(f"  Upper bound: {upper_bound:.3f}")
    print(f"  Number of outliers: {len(outliers)}")
    if len(outliers) > 0:
        print(f"  Outlier values: {outliers[col].values}")
# Out:
# === OUTLIER DETECTION USING IQR METHOD ===
#
# sepal_length:
#   Lower bound: 3.150
#   Upper bound: 8.350
#   Number of outliers: 0
#
# sepal_width:
#   Lower bound: 2.050
#   Upper bound: 4.050
#   Number of outliers: 4
#   Outlier values: [4.4 4.1 4.2 2. ]
#
# petal_length:
#   Lower bound: -3.650
#   Upper bound: 10.350
#   Number of outliers: 0
#
# petal_width:
#   Lower bound: -1.950
#   Upper bound: 4.050
#   Number of outliers: 0

# %%
# Calculate correlation matrix
correlation_matrix = df[numerical_cols].corr()

print("=== CORRELATION MATRIX ===")
print(correlation_matrix)

# Create correlation heatmap
plt.figure(figsize=(10, 8))
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            center=0,
            square=True,
            fmt='.3f',
            cbar_kws={'shrink': 0.8},
            mask=mask)
plt.title('Feature Correlation Heatmap', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# Identify highly correlated features
print("\n=== HIGHLY CORRELATED FEATURE PAIRS ===")
high_corr_pairs = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        corr_val = correlation_matrix.iloc[i, j]
        if abs(corr_val) > 0.7:  # Threshold for high correlation
            high_corr_pairs.append((correlation_matrix.columns[i],
                                  correlation_matrix.columns[j],
                                  corr_val))

if high_corr_pairs:
    for pair in high_corr_pairs:
        print(f"{pair[0]} - {pair[1]}: {pair[2]:.3f}")
else:
    print("No highly correlated feature pairs found (threshold: 0.7)")
# Out:
# === CORRELATION MATRIX ===
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000
# === HIGHLY CORRELATED FEATURE PAIRS ===
# sepal_length - petal_length: 0.872
# sepal_length - petal_width: 0.818
# petal_length - petal_width: 0.963

# %%
# Create pairplot to show relationships between all features
plt.figure(figsize=(12, 10))
pairplot = sns.pairplot(df, hue=target_col, markers=["o", "s", "D"])
pairplot.fig.suptitle('Pairplot of Iris Features by Species', y=1.02, fontsize=16, fontweight='bold')
plt.show()

# %%
# Create detailed scatter plots for the most interesting feature pairs
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.ravel()

feature_pairs = [
    (numerical_cols[0], numerical_cols[1]),
    (numerical_cols[0], numerical_cols[2]),
    (numerical_cols[0], numerical_cols[3]),
    (numerical_cols[1], numerical_cols[2]),
    (numerical_cols[1], numerical_cols[3]),
    (numerical_cols[2], numerical_cols[3])
]

colors = ['red', 'blue', 'green']
species_list = df[target_col].unique()

for i, (x_col, y_col) in enumerate(feature_pairs):
    for j, species in enumerate(species_list):
        species_data = df[df[target_col] == species]
        axes[i].scatter(species_data[x_col], species_data[y_col],
                       c=colors[j], label=species, alpha=0.7, s=50)

    axes[i].set_xlabel(x_col, fontsize=10)
    axes[i].set_ylabel(y_col, fontsize=10)
    axes[i].set_title(f'{x_col} vs {y_col}', fontsize=12, fontweight='bold')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Perform statistical tests
print("=== STATISTICAL TESTS ===")

# Test for normality (Shapiro-Wilk test)
print("\n1. NORMALITY TESTS (Shapiro-Wilk)")
print("H0: Data is normally distributed")
print("H1: Data is not normally distributed")
print("p-value < 0.05: Reject H0 (not normal)")

for col in numerical_cols:
    stat, p_value = stats.shapiro(df[col])
    print(f"\n{col}:")
    print(f"  Statistic: {stat:.6f}")
    print(f"  P-value: {p_value:.6f}")
    if p_value < 0.05:
        print(f"  Result: Not normally distributed ❌")
    else:
        print(f"  Result: Normally distributed ✅")

# ANOVA test for each feature across species
print("\n\n2. ANOVA TESTS (One-way)")
print("H0: All species have the same mean for the feature")
print("H1: At least one species has a different mean")
print("p-value < 0.05: Reject H0 (significant difference)")

for col in numerical_cols:
    groups = [df[df[target_col] == species][col] for species in df[target_col].unique()]
    f_stat, p_value = stats.f_oneway(*groups)
    print(f"\n{col}:")
    print(f"  F-statistic: {f_stat:.6f}")
    print(f"  P-value: {p_value:.6f}")
    if p_value < 0.05:
        print(f"  Result: Significant difference between species ✅")
    else:
        print(f"  Result: No significant difference ❌")
# Out:
# === STATISTICAL TESTS ===
#
# 1. NORMALITY TESTS (Shapiro-Wilk)
# H0: Data is normally distributed
# H1: Data is not normally distributed
# p-value < 0.05: Reject H0 (not normal)
#
# sepal_length:
#   Statistic: 0.976090
#   P-value: 0.010181
#   Result: Not normally distributed ❌
#
# sepal_width:
#   Statistic: 0.983792
#   P-value: 0.075179
#   Result: Normally distributed ✅
#
# petal_length:
#   Statistic: 0.876425
#   P-value: 0.000000
#   Result: Not normally distributed ❌
#
# petal_width:
#   Statistic: 0.902625
#   P-value: 0.000000
#   Result: Not normally distributed ❌
#
#
# 2. ANOVA TESTS (One-way)
# H0: All species have the same mean for the feature
# H1: At least one species has a different mean
# p-value < 0.05: Reject H0 (significant difference)
#
# sepal_length:
#   F-statistic: 119.264502
#   P-value: 0.000000
#   Result: Significant difference between species ✅
#
# sepal_width:
#   F-statistic: 47.364461
#   P-value: 0.000000
# ...

# %%
print("=" * 60)
print("                  DATA QUALITY REPORT")
print("=" * 60)

# Dataset overview
print(f"\n📊 DATASET OVERVIEW:")
print(f"   • Total samples: {len(df)}")
print(f"   • Total features: {len(df.columns)}")
print(f"   • Numerical features: {len(numerical_cols)}")
print(f"   • Target classes: {df[target_col].nunique()}")

# Missing values
missing_count = df.isnull().sum().sum()
print(f"\n🔍 DATA COMPLETENESS:")
if missing_count == 0:
    print(f"   • Missing values: None ✅")
    print(f"   • Data completeness: 100% ✅")
else:
    print(f"   • Missing values: {missing_count} ❌")
    print(f"   • Data completeness: {((len(df) * len(df.columns) - missing_count) / (len(df) * len(df.columns))) * 100:.1f}%")

# Class balance
print(f"\n⚖️ CLASS BALANCE:")
class_counts = df[target_col].value_counts()
is_balanced = class_counts.std() / class_counts.mean() < 0.1
if is_balanced:
    print(f"   • Dataset is well balanced ✅")
else:
    print(f"   • Dataset may be imbalanced ⚠️")

for species, count in class_counts.items():
    percentage = (count / len(df)) * 100
    print(f"   • {species}: {count} samples ({percentage:.1f}%)")

# Outliers summary
print(f"\n📈 OUTLIER ANALYSIS:")
total_outliers = 0
for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = len(df[(df[col] < lower_bound) | (df[col] > upper_bound)])
    total_outliers += outliers
    if outliers > 0:
        print(f"   • {col}: {outliers} outliers")

if total_outliers == 0:
    print(f"   • No significant outliers detected ✅")

# Correlation insights
print(f"\n🔗 FEATURE RELATIONSHIPS:")
high_corr_count = 0
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if abs(correlation_matrix.iloc[i, j]) > 0.7:
            high_corr_count += 1

if high_corr_count > 0:
    print(f"   • {high_corr_count} highly correlated feature pairs found")
    print(f"   • Consider feature selection for ML models ⚠️")
else:
    print(f"   • No extremely high correlations detected ✅")

# ML Readiness Assessment
print(f"\n🤖 MACHINE LEARNING READINESS:")
ml_score = 0

# Check completeness
if missing_count == 0:
    ml_score += 25
    print(f"   ✅ No missing values")
else:
    print(f"   ❌ Missing values need handling")

# Check balance
if is_balanced:
    ml_score += 25
    print(f"   ✅ Well-balanced classes")
else:
    print(f"   ⚠️ Class imbalance may need addressing")

# Check data types
if len(numerical_cols) == len(df.columns) - 1:  # All except target are numerical
    ml_score += 25
    print(f"   ✅ All features are numerical")
else:
    print(f"   ⚠️ Some non-numerical features may need encoding")

# Check size
if len(df) > 100:
    ml_score += 25
    print(f"   ✅ Sufficient sample size")
else:
    print(f"   ⚠️ Small sample size")

print(f"\n📋 OVERALL ML READINESS SCORE: {ml_score}/100")

if ml_score >= 80:
    print("🎉 Dataset is READY for machine learning!")
elif ml_score >= 60:
    print("👍 Dataset is MOSTLY READY with minor preprocessing needed")
else:
    print("⚠️ Dataset needs SIGNIFICANT preprocessing before ML")

print("\n" + "=" * 60)
print("                    END OF ANALYSIS")
print("=" * 60)
# Out:
# ...
#                   DATA QUALITY REPORT
# ...
#
# 📊 DATASET OVERVIEW:
#    • Total samples: 150
#    • Total features: 5
#    • Numerical features: 4
#    • Target classes: 3
#
# 🔍 DATA COMPLETENESS:
#    • Missing values: None ✅
#    • Data completeness: 100% ✅
#
# ⚖️ CLASS BALANCE:
#    • Dataset is well balanced ✅
#    • setosa: 50 samples (33.3%)
#    • versicolor: 50 samples (33.3%)
#    • virginica: 50 samples (33.3%)
#
# 📈 OUTLIER ANALYSIS:
#    • sepal_width: 4 outliers
#
# 🔗 FEATURE RELATIONSHIPS:
#    • 3 highly correlated feature pairs found
#    • Consider feature selection for ML models ⚠️
#
# 🤖 MACHINE LEARNING READINESS:
#    ✅ No missing values
#    ✅ Well-balanced classes
#    ✅ All features are numerical
#    ✅ Sufficient sample size
#
# 📋 OVERALL ML READINESS SCORE: 100/100
# 🎉 Dataset is READY for machine learning!
#
# ...
#                     END OF ANALYSIS
# ...

# %%
# Create a summary dataframe
summary_stats = df[numerical_cols].describe()

# Save the summary statistics
summary_stats.to_csv('iris_summary_statistics.csv')
print("✅ Summary statistics saved to 'iris_summary_statistics.csv'")

# Create a simple data profile
data_profile = {
    'Feature': [],
    'Data_Type': [],
    'Missing_Values': [],
    'Unique_Values': [],
    'Mean': [],
    'Std': [],
    'Min': [],
    'Max': []
}

for col in df.columns:
    data_profile['Feature'].append(col)
    data_profile['Data_Type'].append(str(df[col].dtype))
    data_profile['Missing_Values'].append(df[col].isnull().sum())
    data_profile['Unique_Values'].append(df[col].nunique())

    if col in numerical_cols:
        data_profile['Mean'].append(round(df[col].mean(), 3))
        data_profile['Std'].append(round(df[col].std(), 3))
        data_profile['Min'].append(round(df[col].min(), 3))
        data_profile['Max'].append(round(df[col].max(), 3))
    else:
        data_profile['Mean'].append('N/A')
        data_profile['Std'].append('N/A')
        data_profile['Min'].append('N/A')
        data_profile['Max'].append('N/A')

profile_df = pd.DataFrame(data_profile)
profile_df.to_csv('iris_data_profile.csv', index=False)
print("✅ Data profile saved to 'iris_data_profile.csv'")

print("\n🎯 NEXT STEPS RECOMMENDATIONS:")
print("1. The dataset appears to be clean and well-structured")
print("2. Consider feature scaling (StandardScaler/MinMaxScaler) for ML algorithms")
print("3. The dataset is suitable for classification tasks")
print("4. Consider trying algorithms like:")
print("   • Logistic Regression")
print("   • Decision Trees")
print("   • Random Forest")
print("   • Support Vector Machines")
print("   • K-Nearest Neighbors")
print("5. Use train-test split for model validation")
print("6. Consider cross-validation for robust performance estimation")
# Out:
# ✅ Summary statistics saved to 'iris_summary_statistics.csv'
# ✅ Data profile saved to 'iris_data_profile.csv'
#
# 🎯 NEXT STEPS RECOMMENDATIONS:
# 1. The dataset appears to be clean and well-structured
# 2. Consider feature scaling (StandardScaler/MinMaxScaler) for ML algorithms
# 3. The dataset is suitable for classification tasks
# 4. Consider trying algorithms like:
#    • Logistic Regression
#    • Decision Trees
#    • Random Forest
#    • Support Vector Machines
#    • K-Nearest Neighbors
# 5. Use train-test split for model validation
# 6. Consider cross-validation for robust performance estimation
